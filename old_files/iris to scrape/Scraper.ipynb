# %%
from autoscraper import AutoScraper


url = 'https://pink.rs/politika'
wanted_dict = {
    "title":[],
    "url":["https://pink.rs/politika/725424/avion-sa-generalom-pavkovicem-poleteo-iz-finske-uskoro-stize-u-beograd-evo-gde-ce-se-odmah-zaputiti",
          ],
    "date":[],
}

scraper = AutoScraper()
result = scraper.build(url=url, wanted_list=wanted_list)

# %%
pipreqs.pipreqs(
# Out:
# <module 'pipreqs.pipreqs' from 'C:\\Users\\Axe\\AppData\\Roaming\\Python\\Python310\\site-packages\\pipreqs\\pipreqs.py'>

# %%
from autoscraper import AutoScraper
url = "https://kapital.kz/news?page=1"
wanted_list = ['https://kapital.kz/finance/142273/srednevzveshennyj-kurs-dollara-na-birzhe-sostavil-52528-tenge.html']

# Step 2: Build a new scraper and train it
scraper = AutoScraper()
result = scraper.build(url, wanted_list)
print("Scraped results:", result)

# Step 3: Save the scraper config for reuse
scraper.save('example_scraper.json')

# Step 4: Load the scraper later (or in another script/session)
loaded_scraper = AutoScraper()
loaded_scraper.load('example_scraper.json')

# Step 5: Use the loaded scraper to scrape again
new_result = loaded_scraper.get_result_similar('https://kapital.kz/news?page=2')
print("Results from loaded scraper:", new_result)
# Out:
# Scraped results: ['https://kapital.kz/economic/142286/prezidenty-kazahstana-i-rossii-proveli-neformalnuyu-vstrechu.html', 'https://kapital.kz/gosudarstvo/142285/glava-gosudarstva-napravil-telegrammu-soboleznovaniya-prezidentu-turcii.html', 'https://kapital.kz/economic/142283/rejting-mvf-kazahstan-voshel-v-top-50-krupnejshih-ekonomik-mira-v-2026-godu.html', 'https://kapital.kz/naznacheniya/142279/bulat-tanabergenov-naznachen-predsedatelem-komiteta-po-zashite-prav-potrebitelej.html', 'https://kapital.kz/naznacheniya/142278/erlan-akbarov-naznachen-vice-ministrom-energetiki.html', 'https://kapital.kz/gosudarstvo/142277/kasym-zhomart-tokaev-pribyl-s-gosudarstvennym-vizitom-v-moskvu.html', 'https://kapital.kz/economic/142276/kpi-restrukturizaciya-nacelennost-na-rezultaty-v-kazakh-invest-perestroyat-processy.html', 'https://kapital.kz/finance/142275/nurbank-zhyl-songyna-dejin-memlekettik-koemekting-bir-boeligin-khajtarugha-nietti.html', 'https://kapital.kz/economic/142274/v-2026-godu-v-kazahstane-zapustyat-programmu-zakaz-na-investicii.html', 'https://kapital.kz/finance/142273/srednevzveshennyj-kurs-dollara-na-birzhe-sostavil-52528-tenge.html']
# Results from loaded scraper: ['https://kapital.kz/economic/142272/predelnye-ceny-na-lekarstva-mozhno-uznat-cherez-prilozhenie-naqty-onim.html', 'https://kapital.kz/gosudarstvo/142271/v-kazahstane-prodlili-dejstvie-nacionalnoj-procedury-registracii-lekarstv.html', 'https://kapital.kz/economic/142270/poryadka-1500-gruzovyh-avto-skopilos-na-granice-s-kitaem.html', 'https://kapital.kz/economic/142269/2026-zhyly-astanada-geologiyalykh-zerthana-khurylysy-bastalady.html', 'https://kapital.kz/finance/142268/do-konca-goda-nurbank-nameren-vernut-chast-gospomoshi.html', 'https://kapital.kz/finance/142266/cherez-internet-i-mobilnyj-telefon-prohodit-70percent-operacij-po-kartam.html', 'https://kapital.kz/naznacheniya/142265/naznachen-posol-kazahstana-v-kongo.html', 'https://kapital.kz/naznacheniya/142264/madiyar-menilbekov-naznachen-poslom-kazahstana-v-bahrejne.html', 'https://kapital.kz/lifestyle/142257/ot-almaty-do-amsterdama-kak-kazahstanskaya-kultura-zavoevyvaet-evropu.html', 'https://kapital.kz/economic/142263/ne-dopuskat-neobosnovannogo-udorozhaniya-lekarstv-poruchil-premer-antimonopolshikam.html']

# %%
<time datetime="2025-11-11T18:31:08.000Z" class="gz">11.11.2025 · 18:31</time>

# %%
scraper.set_rule_aliases({'rule_0aok': 'title', 'rule_vn5z': 'price', 'rule_buz1': 'url'})

scraper.keep_rules(['rule_0aok', 'rule_vn5z', 'rule_buz1'])

scraper.save('ebay-search')

# %%
url = 'https://www.etsy.com/search?q=macbook'

wanted_dict = {
    'title': [
        'Apple MacBook Pro i9 32GB 500GB Radeon 560X 15.4 2018 Touch Bar 2.9GHz 6-Core', 
        'Laptop MacBook Premium Ergonomic Wood Stand Holder Computer Gift Nerd Tech Geek Mens, woodworking gift, Home office workspace accessories',
    ],
    'price': ['1,500.00', '126.65'],
    'url': ['851553172']
}

scraper = AutoScraper()
scraper.build(url=url, wanted_dict=wanted_dict)

# get results grouped per rule so we'll know which one to use 
scraper.get_result_similar(url, grouped=True)

scraper.keep_rules(['rule_705x', 'rule_70m8', 'rule_d9wp', 'rule_kv6p'])

scraper.save('etsy-search')
